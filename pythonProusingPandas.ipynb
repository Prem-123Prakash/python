# %%
import pandas as pd

# %%
 data = pd.read_csv("true_car_listings.csv")

# %%
data
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df=data.copy()
df.head(3)
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
#
#         Model
# 0  ILX6-Speed
# 1  ILX5-Speed
# 2  ILX6-Speed

# %%
print(df.shape)
# Out:
# (852122, 8)

# %%
print(df.select_dtypes)
# Out:
# <bound method DataFrame.select_dtypes of         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# ...

# %%
df.describe()
# Out:
#                Price           Year       Mileage
# count  852122.000000  852122.000000  8.521220e+05
# mean    21464.100210    2013.289145  5.250779e+04
# std     13596.202241       3.414987  4.198896e+04
# min      1500.000000    1997.000000  5.000000e+00
# 25%     13000.000000    2012.000000  2.383600e+04
# 50%     18500.000000    2014.000000  4.025600e+04
# 75%     26995.000000    2016.000000  7.218600e+04
# max    499500.000000    2018.000000  2.856196e+06

# %%
df.State
# Out:
# 0          TX
# 1          NY
# 2          TX
# 3          CO
# 4          UT
#          ...
# 852117     CA
# 852118     NJ
# 852119     CO
# 852120     CA
# 852121     NY
# Name: State, Length: 852122, dtype: object

# %%
df.isnull()
# Out:
#         Price   Year  Mileage   City  State    Vin   Make  Model
# 0       False  False    False  False  False  False  False  False
# 1       False  False    False  False  False  False  False  False
# 2       False  False    False  False  False  False  False  False
# 3       False  False    False  False  False  False  False  False
# 4       False  False    False  False  False  False  False  False
# ...       ...    ...      ...    ...    ...    ...    ...    ...
# 852117  False  False    False  False  False  False  False  False
# 852118  False  False    False  False  False  False  False  False
# 852119  False  False    False  False  False  False  False  False
# 852120  False  False    False  False  False  False  False  False
# 852121  False  False    False  False  False  False  False  False
#
# [852122 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Price      0
# Year       0
# Mileage    0
# City       0
# State      0
# Vin        0
# Make       0
# Model      0
# dtype: int64

# %%
df.iloc[1:4,2:4]
# Out:
#    Mileage              City
# 1    19606  Long Island City
# 2    48851           El Paso
# 3    39922           Windsor

# %%
df.head()
df.iloc[0]
# Out:
# Price                   8995
# Year                    2014
# Mileage                35725
# City                 El Paso
# State                     TX
# Vin        19VDE2E53EE000083
# Make                   Acura
# Model             ILX6-Speed
# Name: 0, dtype: object

# %%
print(df.head())
df.iloc[0]
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic
# Price                   8995
# Year                    2014
# Mileage                35725
# City                 El Paso
# State                     TX
# Vin        19VDE2E53EE000083
# Make                   Acura
# Model             ILX6-Speed
# Name: 0, dtype: object

# %%
print(df.head())
print(df.iloc[0])
print(df.loc[0])
# Out:
#    Price  Year  Mileage              City State                Vin   Make  \
# 0   8995  2014    35725           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013    19606  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model
# 0    ILX6-Speed
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic
# Price                   8995
# Year                    2014
# Mileage                35725
# City                 El Paso
# State                     TX
# Vin        19VDE2E53EE000083
# Make                   Acura
# Model             ILX6-Speed
# Name: 0, dtype: object
# Price                   8995
# Year                    2014
# Mileage                35725
# City                 El Paso
# State                     TX
# ...

# %%
data
# Out:
#         Price  Year  Mileage              City State                Vin  \
# 0        8995  2014    35725           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013    19606  Long Island City    NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso    TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor    CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon    UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...   ...                ...
# 852117  63215  2017        9       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0       Acura    ILX6-Speed
# 1       Acura    ILX5-Speed
# ...

# %%
#for add a new row
df.loc[0]=[234,2000,433,"Samastipur","Bihar","123SDF04JHG","Nike","SQ23ER"]
df.head()
# Out:
#    Price  Year  Mileage              City  State                Vin   Make  \
# 0    234  2000      433        Samastipur  Bihar        123SDF04JHG   Nike
# 1  10888  2013    19606  Long Island City     NY  19VDE1F52DE012636  Acura
# 2   8995  2013    48851           El Paso     TX  19VDE2E52DE000025  Acura
# 3  10999  2014    39922           Windsor     CO  19VDE1F71EE003817  Acura
# 4  14799  2016    22142            Lindon     UT  19UDE2F32GA001284  Acura
#
#           Model
# 0        SQ23ER
# 1    ILX5-Speed
# 2    ILX6-Speed
# 3    ILX5-Speed
# 4  ILXAutomatic

# %%
#manipulating data in data frame
df.reset_index()
# Out:
#          index  Price  Year  Mileage              City  State  \
# 0            0    234  2000      433        Samastipur  Bihar
# 1            1  10888  2013    19606  Long Island City     NY
# 2            2   8995  2013    48851           El Paso     TX
# 3            3  10999  2014    39922           Windsor     CO
# 4            4  14799  2016    22142            Lindon     UT
# ...        ...    ...   ...      ...               ...    ...
# 852117  852117  63215  2017        9       Culver City     CA
# 852118  852118  72260  2017     3201         Englewood     NJ
# 852119  852119  55999  2016    28941      Fort Collins     CO
# 852120  852120  60240  2017     3005       San Leandro     CA
# 852121  852121  76995  2017     2502          New York     NY
#
#                       Vin   Make         Model
# 0             123SDF04JHG   Nike        SQ23ER
# 1       19VDE1F52DE012636  Acura    ILX5-Speed
# 2       19VDE2E52DE000025  Acura    ILX6-Speed
# ...

# %%
df.reset_index(drop=True)
# Out:
#         Price  Year  Mileage              City  State                Vin  \
# 0         234  2000      433        Samastipur  Bihar        123SDF04JHG
# 1       10888  2013    19606  Long Island City     NY  19VDE1F52DE012636
# 2        8995  2013    48851           El Paso     TX  19VDE2E52DE000025
# 3       10999  2014    39922           Windsor     CO  19VDE1F71EE003817
# 4       14799  2016    22142            Lindon     UT  19UDE2F32GA001284
# ...       ...   ...      ...               ...    ...                ...
# 852117  63215  2017        9       Culver City     CA  YV1A22MK9H1013237
# 852118  72260  2017     3201         Englewood     NJ  YV4A22PL3H1186162
# 852119  55999  2016    28941      Fort Collins     CO  YV4A22PL4G1000868
# 852120  60240  2017     3005       San Leandro     CA  YV4A22NLXH1006162
# 852121  76995  2017     2502          New York     NY  YV4BC0ZX1H1109845
#
#          Make         Model
# 0        Nike        SQ23ER
# 1       Acura    ILX5-Speed
# ...

# %%
df.reset_index(drop=True,inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=852122, step=1)

# %%
#delete a col.
df.drop('Vin',axis=1)
# Out:
#         Price  Year  Mileage              City  State   Make         Model
# 0         234  2000      433        Samastipur  Bihar   Nike        SQ23ER
# 1       10888  2013    19606  Long Island City     NY  Acura    ILX5-Speed
# 2        8995  2013    48851           El Paso     TX  Acura    ILX6-Speed
# 3       10999  2014    39922           Windsor     CO  Acura    ILX5-Speed
# 4       14799  2016    22142            Lindon     UT  Acura  ILXAutomatic
# ...       ...   ...      ...               ...    ...    ...           ...
# 852117  63215  2017        9       Culver City     CA  Volvo         S90T6
# 852118  72260  2017     3201         Englewood     NJ  Volvo        XC90T6
# 852119  55999  2016    28941      Fort Collins     CO  Volvo       XC90AWD
# 852120  60240  2017     3005       San Leandro     CA  Volvo           V90
# 852121  76995  2017     2502          New York     NY  Volvo        XC90T8
#
# [852122 rows x 7 columns]

# %%
#for data back
df=data.copy()
df.columns=['Price','Year','Mileage','City','State','Vin','Make','Model']
df.describe()
df.tail()
# Out:
#         Price  Year  Mileage          City State                Vin   Make  \
# 852117  63215  2017        9   Culver City    CA  YV1A22MK9H1013237  Volvo
# 852118  72260  2017     3201     Englewood    NJ  YV4A22PL3H1186162  Volvo
# 852119  55999  2016    28941  Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 852120  60240  2017     3005   San Leandro    CA  YV4A22NLXH1006162  Volvo
# 852121  76995  2017     2502      New York    NY  YV4BC0ZX1H1109845  Volvo
#
#           Model
# 852117    S90T6
# 852118   XC90T6
# 852119  XC90AWD
# 852120      V90
# 852121   XC90T8

# %%
#add a column
df["diff_Price_Mileage"]=df["Price"]-df["Mileage"]
df.tail()
# Out:
#         Price  Year  Mileage          City State                Vin   Make  \
# 852117  63215  2017        9   Culver City    CA  YV1A22MK9H1013237  Volvo
# 852118  72260  2017     3201     Englewood    NJ  YV4A22PL3H1186162  Volvo
# 852119  55999  2016    28941  Fort Collins    CO  YV4A22PL4G1000868  Volvo
# 852120  60240  2017     3005   San Leandro    CA  YV4A22NLXH1006162  Volvo
# 852121  76995  2017     2502      New York    NY  YV4BC0ZX1H1109845  Volvo
#
#           Model  diff_Price_Mileage
# 852117    S90T6               63206
# 852118   XC90T6               69059
# 852119  XC90AWD               27058
# 852120      V90               57235
# 852121   XC90T8               74493

# %%
#work on null values
df.isnull()
# Out:
#         Price   Year  Mileage   City  State    Vin   Make  Model  \
# 0       False  False    False  False  False  False  False  False
# 1       False  False    False  False  False  False  False  False
# 2       False  False    False  False  False  False  False  False
# 3       False  False    False  False  False  False  False  False
# 4       False  False    False  False  False  False  False  False
# ...       ...    ...      ...    ...    ...    ...    ...    ...
# 852117  False  False    False  False  False  False  False  False
# 852118  False  False    False  False  False  False  False  False
# 852119  False  False    False  False  False  False  False  False
# 852120  False  False    False  False  False  False  False  False
# 852121  False  False    False  False  False  False  False  False
#
#         diff_Price_Mileage
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...

# %%
import numpy as np
df.iloc[2:4,1:3]=np.nan
df.head()
# Out:
#    Price    Year  Mileage              City State                Vin   Make  \
# 0   8995  2014.0  35725.0           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013.0  19606.0  Long Island City    NY  19VDE1F52DE012636  Acura
# 2   8995     NaN      NaN           El Paso    TX  19VDE2E52DE000025  Acura
# 3  10999     NaN      NaN           Windsor    CO  19VDE1F71EE003817  Acura
# 4  14799  2016.0  22142.0            Lindon    UT  19UDE2F32GA001284  Acura
#
#           Model  diff_Price_Mileage
# 0    ILX6-Speed              -26730
# 1    ILX5-Speed               -8718
# 2    ILX6-Speed              -39856
# 3    ILX5-Speed              -28923
# 4  ILXAutomatic               -7343

# %%
df.isnull()
# Out:
#         Price   Year  Mileage   City  State    Vin   Make  Model  \
# 0       False  False    False  False  False  False  False  False
# 1       False  False    False  False  False  False  False  False
# 2       False   True     True  False  False  False  False  False
# 3       False   True     True  False  False  False  False  False
# 4       False  False    False  False  False  False  False  False
# ...       ...    ...      ...    ...    ...    ...    ...    ...
# 852117  False  False    False  False  False  False  False  False
# 852118  False  False    False  False  False  False  False  False
# 852119  False  False    False  False  False  False  False  False
# 852120  False  False    False  False  False  False  False  False
# 852121  False  False    False  False  False  False  False  False
#
#         diff_Price_Mileage
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...

# %%
df.describe()
# Out:
#                Price           Year       Mileage  diff_Price_Mileage
# count  852122.000000  852120.000000  8.521200e+05        8.521220e+05
# mean    21464.100210    2013.289145  5.250781e+04       -3.104369e+04
# std     13596.202241       3.414991  4.198901e+04        4.928377e+04
# min      1500.000000    1997.000000  5.000000e+00       -2.851263e+06
# 25%     13000.000000    2012.000000  2.383600e+04       -5.569775e+04
# 50%     18500.000000    2014.000000  4.025600e+04       -1.979600e+04
# 75%     26995.000000    2016.000000  7.218600e+04        9.050000e+02
# max    499500.000000    2018.000000  2.856196e+06        4.962400e+05

# %%
df.dropna()
# Out:
#         Price    Year   Mileage              City State                Vin  \
# 0        8995  2014.0   35725.0           El Paso    TX  19VDE2E53EE000083
# 1       10888  2013.0   19606.0  Long Island City    NY  19VDE1F52DE012636
# 4       14799  2016.0   22142.0            Lindon    UT  19UDE2F32GA001284
# 5        7989  2012.0  105246.0             Miami    FL  JH4CU2F83CC019895
# 6       14490  2014.0   34032.0         Greatneck    NY  JH4CU2F84EC002686
# ...       ...     ...       ...               ...   ...                ...
# 852117  63215  2017.0       9.0       Culver City    CA  YV1A22MK9H1013237
# 852118  72260  2017.0    3201.0         Englewood    NJ  YV4A22PL3H1186162
# 852119  55999  2016.0   28941.0      Fort Collins    CO  YV4A22PL4G1000868
# 852120  60240  2017.0    3005.0       San Leandro    CA  YV4A22NLXH1006162
# 852121  76995  2017.0    2502.0          New York    NY  YV4BC0ZX1H1109845
#
#          Make         Model  diff_Price_Mileage
# ...

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    Price    Year   Mileage              City State                Vin   Make  \
# 0   8995  2014.0   35725.0           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013.0   19606.0  Long Island City    NY  19VDE1F52DE012636  Acura
# 4  14799  2016.0   22142.0            Lindon    UT  19UDE2F32GA001284  Acura
# 5   7989  2012.0  105246.0             Miami    FL  JH4CU2F83CC019895  Acura
# 6  14490  2014.0   34032.0         Greatneck    NY  JH4CU2F84EC002686  Acura
#
#           Model  diff_Price_Mileage
# 0    ILX6-Speed              -26730
# 1    ILX5-Speed               -8718
# 4  ILXAutomatic               -7343
# 5  TSXAutomatic              -97257
# 6    TSXSpecial              -19542

# %%
#again for reseting the data
df.head()
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#    Price    Year   Mileage              City State                Vin   Make  \
# 0   8995  2014.0   35725.0           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013.0   19606.0  Long Island City    NY  19VDE1F52DE012636  Acura
# 2  14799  2016.0   22142.0            Lindon    UT  19UDE2F32GA001284  Acura
# 3   7989  2012.0  105246.0             Miami    FL  JH4CU2F83CC019895  Acura
# 4  14490  2014.0   34032.0         Greatneck    NY  JH4CU2F84EC002686  Acura
#
#           Model  diff_Price_Mileage
# 0    ILX6-Speed              -26730
# 1    ILX5-Speed               -8718
# 2  ILXAutomatic               -7343
# 3  TSXAutomatic              -97257
# 4    TSXSpecial              -19542

# %%
#now we are going to filled a data inplace of nan value
df.Year.fillna(df.Year.mean(),inplace=True)
df.Mileage.fillna(df.Mileage.mean(),inplace=True)
df.head()
# Out:
#    Price    Year   Mileage              City State                Vin   Make  \
# 0   8995  2014.0   35725.0           El Paso    TX  19VDE2E53EE000083  Acura
# 1  10888  2013.0   19606.0  Long Island City    NY  19VDE1F52DE012636  Acura
# 2  14799  2016.0   22142.0            Lindon    UT  19UDE2F32GA001284  Acura
# 3   7989  2012.0  105246.0             Miami    FL  JH4CU2F83CC019895  Acura
# 4  14490  2014.0   34032.0         Greatneck    NY  JH4CU2F84EC002686  Acura
#
#           Model  diff_Price_Mileage
# 0    ILX6-Speed              -26730
# 1    ILX5-Speed               -8718
# 2  ILXAutomatic               -7343
# 3  TSXAutomatic              -97257
# 4    TSXSpecial              -19542
